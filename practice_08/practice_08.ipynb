# %%
"""
実践1. pythonの比較演算子('==', '!=', '>', '<', '>=', '<=')をすべて検証してください。
例: 変数に値を入れる。その値と別の値を比較し、それぞれの比較演算子を満たす場合はprintを出力する。
"""
num = 100

if num == 100:
    print(f"numは100です")

if num != 0:
    print(f"numは{num}であり、0ではありません")

if num > 50:
    print(f"numは{num}であり、50より大きいです")

if num < 200:
    print(f"numは{num}であり、200未満です")

if num >= 80:
    print(f"numは{num}であり、80以上です")

if num <= 150:
    print(f"numは{num}であり、150以下です")
# Out:
# numは100です
# numは100であり、0ではありません
# numは100であり、50より大きいです
# numは100であり、200未満です
# numは100であり、80以上です
# numは100であり、150以下です

# %%
"""
実践2. 数値を入力し、その数値が正の数なら"正の数(2)です"、負の数なら"負の数(-5)です"、0なら"0です"と出力するプログラムを作成してください。()内の数値はfで出力してください。
入力は変数にそのまま入れてもよいですし、input()を用いてもよいです。ただし数値の場合はintやfloatへの変換が必要です。
"""
num = float(input())

if num == 0:
    print(f"0です")
elif num < 0:
    print(f"負の数({num})です")
else:
    print(f"正の数({num})です")
# Out:
# 2
# 正の数(2.0)です

# %%
"""
実践3. 年齢を入力し、20歳以上なら"成人です"、20歳未満なら"未成年です"と出力するプログラムを作成してください。
"""
age = float(input("年齢を入力してください"))

if age >= 20:
    print("成人です")
else:
    print("未成年です")
# Out:
# 年齢を入力してください20
# 成人です

# %%
"""
実践4. 2つの数値を入力し、大きい方の数値を出力するプログラムを作成してください。ただし、2つの数値が同じ場合は"同じ値です"と出力してください。
"""
num1 = float(input("1つ目の数値を入力してください"))
num2 = float(input("2つ目の数値を入力してください"))

if num1 == num2:
    print("同じ値です")
elif num1 > num2:
    print(f"大きいのは{num1}です")
else:
    print(f"大きいのは{num2}です")
# Out:
# 1つ目の数値を入力してください20
# 2つ目の数値を入力してください20
# 同じ値です

# %%
"""
実践5. 西暦の年を入力し、その年がうるう年かどうかを判定するプログラムを作成してください。うるう年の条件は以下です。
"""
year = float(input("西暦を入力してください"))

if year % 400 == 0:
    print("うるう年です")
elif year % 100 == 0:
    print("うるう年ではありません")
elif year % 4 == 0:
    print("うるう年です")
else:
    print("うるう年ではありません")
# Out:
# 西暦を入力してください2024
# うるう年です
