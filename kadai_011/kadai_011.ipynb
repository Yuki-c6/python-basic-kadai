# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# forを使用した場合
for planet in array:
    print(planet)

# whileを使用した場合
i = 0
while i <  len(array):
    print(array[i])
    i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
